# %%
import requests
import pandas as pd

ano = "1973"

url = "https://opendata.aemet.es/opendata/api/valores/climatologicos/mensualesanuales/datos/anioini/"+ano+"/aniofin/"+ano+"/estacion/1082"

querystring = {"api_key":"eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJtYXJ0aW5lenBhcmRvZGllZ29AZ21haWwuY29tIiwianRpIjoiYTU1YjczNDktYjIxOS00MWRiLTg5YzktYzRiNWU1NWI3OTdmIiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE3MTQ5OTc0NzAsInVzZXJJZCI6ImE1NWI3MzQ5LWIyMTktNDFkYi04OWM5LWM0YjVlNTViNzk3ZiIsInJvbGUiOiIifQ.PaduQ1vHGQCTaWPEhsYpmFKSC1jrGoa6H8dWDzKqNYs"}

headers = {
    'cache-control': "no-cache"
     }

response = requests.request("GET", url, headers=headers, params=querystring)
valor = response.json()
endpoint = valor['datos']


clima = pd.read_json(endpoint)
clima
# Out:
#       fecha  indicativo         p_max  n_cub  hr  n_gra  n_fog  inso  \
# 0   1973-10        1082      19.9(01)      9  73      0     11   4.7
# 1   1973-11        1082      26.0(11)      8  74      1      2   4.9
# 2   1973-12        1082      31.7(24)     17  78      0      5   2.0
# 3   1973-13        1082  56.1(15/ago)    157  74      6     55   4.3
# 4    1973-1        1082      42.8(31)     15  75      1     10   2.4
# 5    1973-2        1082      50.7(19)     17  77      1      4   3.1
# 6    1973-3        1082      13.4(24)      8  67      0      1   5.3
# 7    1973-4        1082      35.9(09)     12  68      0      2   5.1
# 8    1973-5        1082      41.0(31)     12  64      2      2   6.2
# 9    1973-6        1082      22.0(05)     16  77      0      7   4.0
# 10   1973-7        1082      12.6(24)     19  76      0      3   3.8
# 11   1973-8        1082      56.1(15)     12  80      0      5   5.0
# 12   1973-9        1082      53.0(30)     12  75      1      3   5.0
#
# ...

# %% [markdown]
# # Accedemos a la API de aemet Open Data, probamos la descarga de datos para el primer año

# %% [markdown]
# #Creo un bucle para acceder a la API de aemet Open Data y descargo la info de los datos y estaciones meteorológicas deseadas

# %%
import requests
import pandas as pd

listaano= []

#ano = "1973"

# Guardo el periodo de años en una lista como string
for ano in range(2014,2024,1):
  ano = str(ano)
  listaano.append(ano)

# Bucle que guarda la info de cada año
for ano in listaano:

  url = "https://opendata.aemet.es/opendata/api/valores/climatologicos/mensualesanuales/datos/anioini/"+ano+"/aniofin/"+ano+"/estacion/1082"

  querystring = {"api_key":"eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJtYXJ0aW5lenBhcmRvZGllZ29AZ21haWwuY29tIiwianRpIjoiYTU1YjczNDktYjIxOS00MWRiLTg5YzktYzRiNWU1NWI3OTdmIiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE3MTQ5OTc0NzAsInVzZXJJZCI6ImE1NWI3MzQ5LWIyMTktNDFkYi04OWM5LWM0YjVlNTViNzk3ZiIsInJvbGUiOiIifQ.PaduQ1vHGQCTaWPEhsYpmFKSC1jrGoa6H8dWDzKqNYs"}

  headers = {
      'cache-control': "no-cache"
      }

  response = requests.request("GET", url, headers=headers, params=querystring)
  valor = response.json()
  endpoint = valor['datos']


  df = pd.read_json(endpoint)


  clima = pd.concat([clima, df], axis=0)      #Concatenamos los datos

clima
# Out:
#       fecha  indicativo         p_max  n_cub    hr  n_gra  n_fog  inso  \
# 0   1973-10        1082      19.9(01)    9.0  73.0    0.0   11.0   4.7
# 1   1973-11        1082      26.0(11)    8.0  74.0    1.0    2.0   4.9
# 2   1973-12        1082      31.7(24)   17.0  78.0    0.0    5.0   2.0
# 3   1973-13        1082  56.1(15/ago)  157.0  74.0    6.0   55.0   4.3
# 4    1973-1        1082      42.8(31)   15.0  75.0    1.0   10.0   2.4
# ..      ...         ...           ...    ...   ...    ...    ...   ...
# 8    2023-8        1082      22.2(28)   14.0  72.0    0.0    0.0   6.2
# 9    2023-9        1082      31.7(16)    7.0  72.0    0.0    1.0   6.0
# 10  2023-11        1082      27.2(30)   17.0  77.0    0.0    2.0   2.8
# 11  2023-12        1082      35.6(01)   18.0  75.0    0.0    3.0   2.7
# 12  2023-13        1082  94.6(16/ene)  159.0  71.0    3.0   16.0   4.8
#
#              q_max  nw_55  ...  nt_00  ti_max  n_nie tm_mes  tm_max  nv_0100  \
# ...

# %% [markdown]
# #Vemos la info de las columnas

# %%
clima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 793 entries, 0 to 12
# Data columns (total 43 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   fecha       793 non-null    object
#  1   indicativo  793 non-null    int64
#  2   p_max       788 non-null    object
#  3   n_cub       788 non-null    float64
#  4   hr          782 non-null    float64
#  5   n_gra       788 non-null    float64
#  6   n_fog       788 non-null    float64
#  7   inso        771 non-null    float64
#  8   q_max       786 non-null    object
#  9   nw_55       765 non-null    float64
#  10  q_mar       784 non-null    float64
#  11  q_med       788 non-null    float64
#  12  tm_min      788 non-null    float64
#  13  ta_max      788 non-null    object
#  14  ts_min      788 non-null    float64
#  15  nt_30       788 non-null    float64
#  16  nv_0050     786 non-null    float64
#  17  n_des       788 non-null    float64
#  18  w_racha     767 non-null    object
# ...

# %%
print(f'Total de filas duplicadas: {clima.duplicated().sum()}')
# Out:
# Total de filas duplicadas: 130

# %%
Clima = clima.drop_duplicates()

# %%
Clima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 663 entries, 0 to 12
# Data columns (total 43 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   fecha       663 non-null    object
#  1   indicativo  663 non-null    int64
#  2   p_max       658 non-null    object
#  3   n_cub       658 non-null    float64
#  4   hr          652 non-null    float64
#  5   n_gra       658 non-null    float64
#  6   n_fog       658 non-null    float64
#  7   inso        641 non-null    float64
#  8   q_max       656 non-null    object
#  9   nw_55       637 non-null    float64
#  10  q_mar       654 non-null    float64
#  11  q_med       658 non-null    float64
#  12  tm_min      658 non-null    float64
#  13  ta_max      658 non-null    object
#  14  ts_min      658 non-null    float64
#  15  nt_30       658 non-null    float64
#  16  nv_0050     656 non-null    float64
#  17  n_des       658 non-null    float64
#  18  w_racha     639 non-null    object
# ...

# %%
Clima.isnull().sum()
# Out:
# fecha           0
# indicativo      0
# p_max           5
# n_cub           5
# hr             11
# n_gra           5
# n_fog           5
# inso           22
# q_max           7
# nw_55          26
# q_mar           9
# q_med           5
# tm_min          5
# ta_max          5
# ts_min          5
# nt_30           5
# nv_0050         7
# n_des           5
# w_racha        24
# np_100          5
# n_nub           5
# p_sol          22
# nw_91          26
# np_001          5
# ta_min          5
# e              13
# np_300          5
# nv_1000         7
# evap          309
# p_mes           5
# n_llu           5
# n_tor           5
# w_med           5
# nt_00           5
# ti_max          5
# n_nie           5
# tm_mes          5
# tm_max          5
# nv_0100         7
# q_min           7
# np_010          5
# w_rec         189
# glo           220
# dtype: int64

# %% [markdown]
# # Elimino algunas columnas que no voy a utilizar y las cambio de nombre para trabajar mejor con ellas

# %%
Clima = Clima[['indicativo','fecha','n_cub','n_fog','n_des','n_nub','np_001','tm_min','tm_max','tm_mes','ta_min','ta_max','ts_min','p_max','p_mes','n_tor','w_med']]
Clima = Clima.rename(columns = {'n_cub':'días_cubiertos','n_fog':'días_niebla','n_des':'días_despejado','n_nub':'días_nublados','np_001':'días_con_lluvia','tm_min':'tmedia_min','tm_max':'tmedia_max','tm_mes':'tmedia_mes','ta_min':'tminima','ta_max':'tmaxima','n_tor':'días_tormenta','w_med':'viento'})

Clima
# Out:
#     indicativo    fecha  días_cubiertos  días_niebla  días_despejado  \
# 0         1082  1973-10             9.0         11.0             2.0
# 1         1082  1973-11             8.0          2.0             8.0
# 2         1082  1973-12            17.0          5.0             3.0
# 3         1082  1973-13           157.0         55.0            35.0
# 4         1082   1973-1            15.0         10.0             1.0
# ..         ...      ...             ...          ...             ...
# 8         1082   2023-8            14.0          0.0             5.0
# 9         1082   2023-9             7.0          1.0             5.0
# 10        1082  2023-11            17.0          2.0             1.0
# 11        1082  2023-12            18.0          3.0             3.0
# 12        1082  2023-13           159.0         16.0            36.0
#
#     días_nublados  días_con_lluvia  tmedia_min  tmedia_max  tmedia_mes  \
# ...

# %% [markdown]
# # Separo el año y el mes de la fecha

# %%
Clima['año'] = Clima['fecha'].str.slice(stop=4)
Clima['mes'] = Clima['fecha'].str.slice(start=5)
Clima
# Out:
#     indicativo    fecha  días_cubiertos  días_niebla  días_despejado  \
# 0         1082  1973-10             9.0         11.0             2.0
# 1         1082  1973-11             8.0          2.0             8.0
# 2         1082  1973-12            17.0          5.0             3.0
# 3         1082  1973-13           157.0         55.0            35.0
# 4         1082   1973-1            15.0         10.0             1.0
# ..         ...      ...             ...          ...             ...
# 8         1082   2023-8            14.0          0.0             5.0
# 9         1082   2023-9             7.0          1.0             5.0
# 10        1082  2023-11            17.0          2.0             1.0
# 11        1082  2023-12            18.0          3.0             3.0
# 12        1082  2023-13           159.0         16.0            36.0
#
#     días_nublados  días_con_lluvia  tmedia_min  tmedia_max  tmedia_mes  \
# ...

# %% [markdown]
# # compruebo si la fecha contiene 13 y si contiene 13 lo guardo en un dataframe de resumen

# %%
Clima['mes'] = pd.to_numeric(Clima['mes'])
resumen_anual=Clima[Clima['mes']==13]

resumen_anual.sort_values(by=['año','mes'])
# Out:
#     indicativo    fecha  días_cubiertos  días_niebla  días_despejado  \
# 3         1082  1973-13           157.0         55.0            35.0
# 3         1082  1974-13           185.0         48.0            30.0
# 3         1082  1975-13           154.0         53.0            40.0
# 3         1082  1976-13           126.0         38.0            42.0
# 3         1082  1977-13           152.0         37.0            25.0
# 3         1082  1978-13           164.0         39.0            37.0
# 3         1082  1979-13           171.0         28.0            36.0
# 3         1082  1980-13           151.0         20.0            40.0
# 3         1082  1981-13           152.0         28.0            34.0
# 3         1082  1982-13           143.0         23.0            33.0
# 3         1082  1983-13           134.0         30.0            50.0
# 3         1082  1984-13           159.0         26.0            45.0
# 3         1082  1985-13           158.0         26.0            47.0
# ...

# %% [markdown]
# # Guardo los datos de todos los meses, menos el resumen anual (mes=13) y los ordeno

# %%
Clima['año'] = pd.to_numeric(Clima['año'])
Clima['mes'] = pd.to_numeric(Clima['mes'])
Clima=Clima[Clima['mes']!=13]

Clima=Clima.sort_values(by=['año','mes'])
Clima.head(24)
# Out:
#     indicativo    fecha  días_cubiertos  días_niebla  días_despejado  \
# 4         1082   1973-1            15.0         10.0             1.0
# 5         1082   1973-2            17.0          4.0             3.0
# 6         1082   1973-3             8.0          1.0             6.0
# 7         1082   1973-4            12.0          2.0             4.0
# 8         1082   1973-5            12.0          2.0             1.0
# 9         1082   1973-6            16.0          7.0             2.0
# 10        1082   1973-7            19.0          3.0             0.0
# 11        1082   1973-8            12.0          5.0             1.0
# 12        1082   1973-9            12.0          3.0             4.0
# 0         1082  1973-10             9.0         11.0             2.0
# 1         1082  1973-11             8.0          2.0             8.0
# 2         1082  1973-12            17.0          5.0             3.0
# 4         1082   1974-1            15.0          5.0             4.0
# ...

# %% [markdown]
# # Transformamos la columna fecha en un valor tipo fecha

# %%
Clima['fecha'] = pd.to_datetime (Clima['fecha'])
Clima
# Out:
#     indicativo      fecha  días_cubiertos  días_niebla  días_despejado  \
# 4         1082 1973-01-01            15.0         10.0             1.0
# 5         1082 1973-02-01            17.0          4.0             3.0
# 6         1082 1973-03-01             8.0          1.0             6.0
# 7         1082 1973-04-01            12.0          2.0             4.0
# 8         1082 1973-05-01            12.0          2.0             1.0
# ..         ...        ...             ...          ...             ...
# 8         1082 2023-08-01            14.0          0.0             5.0
# 9         1082 2023-09-01             7.0          1.0             5.0
# 0         1082 2023-10-01            11.0          2.0             5.0
# 10        1082 2023-11-01            17.0          2.0             1.0
# 11        1082 2023-12-01            18.0          3.0             3.0
#
#     días_nublados  días_con_lluvia  tmedia_min  tmedia_max  tmedia_mes  \
# ...

# %% [markdown]
# #Convertimos las columnas de tipo object a string para poder operar con ellas y eliminar las partes que están entre (), después los convierto en float

# %%
Clima['tminima'] = Clima['tminima'].astype("string")
Clima['tmaxima'] = Clima['tmaxima'].astype("string")
Clima['p_max'] = Clima['p_max'].astype("string")
Clima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 612 entries, 4 to 11
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   indicativo       612 non-null    int64
#  1   fecha            612 non-null    datetime64[ns]
#  2   días_cubiertos   609 non-null    float64
#  3   días_niebla      609 non-null    float64
#  4   días_despejado   609 non-null    float64
#  5   días_nublados    609 non-null    float64
#  6   días_con_lluvia  609 non-null    float64
#  7   tmedia_min       609 non-null    float64
#  8   tmedia_max       609 non-null    float64
#  9   tmedia_mes       609 non-null    float64
#  10  tminima          609 non-null    string
#  11  tmaxima          609 non-null    string
#  12  ts_min           609 non-null    float64
#  13  p_max            609 non-null    string
#  14  p_mes            609 non-null    float64
#  15  días_tormenta    609 non-null    float64
# ...

# %%
separatminima = Clima['tminima'].str.split("(", n=1, expand=True)
Clima['tminima']=separatminima[0]

separatmaxima = Clima['tmaxima'].str.split("(", n=1, expand=True)
Clima['tmaxima']=separatmaxima[0]

separap_max = Clima['p_max'].str.split("(", n=1, expand=True)
Clima['p_max']=separap_max[0]

Clima['tminima'] = Clima['tminima'].astype("float")
Clima['tmaxima'] = Clima['tmaxima'].astype("float")
Clima['p_max'] = Clima['p_max'].astype("float")
Clima
# Out:
#     indicativo      fecha  días_cubiertos  días_niebla  días_despejado  \
# 4         1082 1973-01-01            15.0         10.0             1.0
# 5         1082 1973-02-01            17.0          4.0             3.0
# 6         1082 1973-03-01             8.0          1.0             6.0
# 7         1082 1973-04-01            12.0          2.0             4.0
# 8         1082 1973-05-01            12.0          2.0             1.0
# ..         ...        ...             ...          ...             ...
# 8         1082 2023-08-01            14.0          0.0             5.0
# 9         1082 2023-09-01             7.0          1.0             5.0
# 0         1082 2023-10-01            11.0          2.0             5.0
# 10        1082 2023-11-01            17.0          2.0             1.0
# 11        1082 2023-12-01            18.0          3.0             3.0
#
#     días_nublados  días_con_lluvia  tmedia_min  tmedia_max  tmedia_mes  \
# ...

# %% [markdown]
# # Limpieza de datos
# # Compruebo si hay nulos y si es así veo cómo actuar

# %%
 Clima.isnull().sum()
# Out:
# indicativo         0
# fecha              0
# días_cubiertos     3
# días_niebla        3
# días_despejado     3
# días_nublados      3
# días_con_lluvia    3
# tmedia_min         3
# tmedia_max         3
# tmedia_mes         3
# tminima            3
# tmaxima            3
# ts_min             3
# p_max              3
# p_mes              3
# días_tormenta      3
# viento             3
# año                0
# mes                0
# dtype: int64

# %%
nulos=Clima.columns[Clima.isnull().any()]
Clima[nulos].isnull().sum()
print(Clima[Clima.isnull().any(axis=1)][nulos])
# Out:
#    días_cubiertos  días_niebla  días_despejado  días_nublados  \
# 1             NaN          NaN             NaN            NaN
# 2             NaN          NaN             NaN            NaN
# 4             NaN          NaN             NaN            NaN
#
#    días_con_lluvia  tmedia_min  tmedia_max  tmedia_mes  tminima  tmaxima  \
# 1              NaN         NaN         NaN         NaN      NaN      NaN
# 2              NaN         NaN         NaN         NaN      NaN      NaN
# 4              NaN         NaN         NaN         NaN      NaN      NaN
#
#    ts_min  p_max  p_mes  días_tormenta  viento
# 1     NaN    NaN    NaN            NaN     NaN
# 2     NaN    NaN    NaN            NaN     NaN
# 4     NaN    NaN    NaN            NaN     NaN

# %% [markdown]
# #Tenemos algunos nulos, vamos a substituirlos por el valor medio de su columna correspondiente para que no existan problemas a la hora de hacer algún cálculo determinado

# %%
Clima=Clima.fillna(Clima.mean())
Clima.isnull().sum()
# Out:
# indicativo         0
# fecha              0
# días_cubiertos     0
# días_niebla        0
# días_despejado     0
# días_nublados      0
# días_con_lluvia    0
# tmedia_min         0
# tmedia_max         0
# tmedia_mes         0
# tminima            0
# tmaxima            0
# ts_min             0
# p_max              0
# p_mes              0
# días_tormenta      0
# viento             0
# año                0
# mes                0
# dtype: int64

# %% [markdown]
# # Compruebo si existen filas duplicadas

# %% [markdown]
# # Vemos una breve descripción categórica de los datos

# %%
Clima.describe()
# Out:
#        indicativo                          fecha  días_cubiertos  días_niebla  \
# count       612.0                            612      612.000000   612.000000
# mean       1082.0  1998-06-16 13:52:56.470588288       12.801314     1.963875
# min        1082.0            1973-01-01 00:00:00        2.000000     0.000000
# 25%        1082.0            1985-09-23 12:00:00       10.000000     1.000000
# 50%        1082.0            1998-06-16 00:00:00       13.000000     2.000000
# 75%        1082.0            2011-03-08 18:00:00       16.000000     3.000000
# max        1082.0            2023-12-01 00:00:00       25.000000    11.000000
# std           0.0                            NaN        4.206798     1.864127
#
#        días_despejado  días_nublados  días_con_lluvia  tmedia_min  tmedia_max  \
# count       612.00000     612.000000       612.000000  612.000000  612.000000
# mean          2.83908      14.793103        14.438424    9.939245   19.516913
# ...

# %% [markdown]
# #Hago una copia

# %%
Clima_Bilbo = Clima.copy(deep=True)

# %%
from google.colab import drive;

drive.mount('/content/drive')

Clima_Bilbo.to_excel('/content/drive/MyDrive/cambio_clima/Clima_Bilbo.xlsx', index = False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

Clima = Clima[['días_cubiertos','días_niebla','días_despejado','días_nublados','días_con_lluvia','tmedia_min','tmedia_max','tmedia_mes','días_tormenta','viento']]


f, ax = plt.subplots(figsize=(12,9))
sns.heatmap(Clima.corr(method='spearman'), annot = True, vmin = -1, vmax = 1, center = 0, cmap = 'coolwarm')
plt.show()

# %%
Clima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 612 entries, 4 to 11
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   días_cubiertos   612 non-null    float64
#  1   días_niebla      612 non-null    float64
#  2   días_despejado   612 non-null    float64
#  3   días_nublados    612 non-null    float64
#  4   días_con_lluvia  612 non-null    float64
#  5   tmedia_min       612 non-null    float64
#  6   tmedia_max       612 non-null    float64
#  7   tmedia_mes       612 non-null    float64
#  8   días_tormenta    612 non-null    float64
#  9   viento           612 non-null    float64
# dtypes: float64(10)
# memory usage: 68.8 KB
